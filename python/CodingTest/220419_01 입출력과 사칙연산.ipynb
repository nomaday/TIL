# %% [markdown]
# ##[단계 1] 입출력과 사칙연산

# %% [markdown]
# ##### No. 2557

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ##### No. 10718

# %%
print("강한친구 대한육군\n강한친구 대한육군")
# Out:
# 강한친구 대한육군
# 강한친구 대한육군

# %% [markdown]
# ##### No. 10171 **

# %%
print("\    /\")
print(")  ( ') ")
print("(  /  )")
print("\(__)|")
# Out:
#   File "<ipython-input-13-26f019eadf64>", line 1
#     print("\    /\")
#                     ^
# SyntaxError: EOL while scanning string literal

# %%
print("\\    /\\ \n)  ( ')\n(  /  )\n\\(__)|")
# Out:
# \    /\
# )  ( ')
# (  /  )
# \(__)|

# %% [markdown]
# ##### No. 10172

# %%
print('|\_/|')
print('|q p|   /}')
print('( 0 )"""\\')
print('|"^"`    |')
print('||_/=\\\\__|')
# Out:
# |\_/|
# |q p|   /}
# ( 0 )"""\
# |"^"`    |
# ||_/=\\__|

# %% [markdown]
# ##### No. 1000 **

# %%
a, b = input().split()
a=int(a)
b=int(b)
print(a+b)
# Out:
# 1 2
# 3

# %% [markdown]
# ##### No. 1001

# %%
a, b=input().split()
a=int(a)
b=int(b)
print(a-b)
# Out:
# 3 2
# 1

# %% [markdown]
# ##### No. 10998

# %%
a, b=input().split()
a=int(a)
b=int(b)
print(a*b)
# Out:
# 3 4
# 12

# %% [markdown]
# ##### No. 1008

# %%
a, b=input().split()
a=int(a)
b=int(b)
print(a/b)
# Out:
# 4 5
# 0.8

# %% [markdown]
# ##### No. 10869

# %%
a, b=input().split()
a=int(a)
b=int(b)
print(a+b)
print(a-b)
print(a*b)
print(int(a/b))
print(a%b)
# Out:
# 7 3
# 10
# 4
# 21
# 2
# 1

# %% [markdown]
# ##### No. 10926

# %%
a = str(input())
print(a + "??!")
# Out:
# baekjoon
# baekjoon??!

# %% [markdown]
# ##### No. 18108

# %%
#1998-2541 = 543
y = int(input())
print(y - 543)
# Out:
# 2541
# 1998

# %% [markdown]
# ##### No. 10430

# %%
a, b, c = input().split()
a = int(a)
b = int(b)
c = int(c)
print((a+b)%c)
print(((a%c)+(b%c))%c)
print((a*b)%c)
print(((a%c)*(b%c))%c)
# Out:
# 5 8 4
# 1
# 1
# 0
# 0

# %% [markdown]
# ##### No. 2588

# %%
a=int(input())
b=input()
print(a* int(b[2]))
print(a* int(b[1]))
print(a* int(b[0]))
print(a*int(b))
# Out:
# 472
# 385
# 2360
# 3776
# 1416
# 181720
